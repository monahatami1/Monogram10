# %% [markdown]
# <a href="https://colab.research.google.com/github/monahatami1/Monogram10/blob/main/Module3_Assignment_House_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# GRADED FUNCTION: house_model
def house_model(y_new):
    xs = np.array([1,2,3,4,5,6],dtype=float)# Your Code Here#
    ys = np.array([1,1.5,2,2.5,3,3.5],dtype=float)# Your Code Here#
    model =keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])]) # Your Code Here#
    model.compile(optimizer='sgd',loss='mean_squared_error')# Your Code Here#)
    model.fit(xs,ys,epochs=1500)# Your Code here#)
    return model.predict(y_new)[0]

# %%
prediction = house_model([7.0])
print(prediction)
# Out:
# Epoch 1/1500
# 1/1 [==============================] - 1s 1s/step - loss: 9.7743
# Epoch 2/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 4.5706
# Epoch 3/1500
# 1/1 [==============================] - 0s 17ms/step - loss: 2.1618
# Epoch 4/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0466
# Epoch 5/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5301
# Epoch 6/1500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2908
# Epoch 7/1500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1796
# Epoch 8/1500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1279
# Epoch 9/1500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1036
# Epoch 10/1500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0920
# Epoch 11/1500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0864
# Epoch 12/1500
# ...
